# %%
import json

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_Peliculas_navideñas= pd.read_csv("./datasets/christmas_movies.csv", index_col=0)

# %%
df_Peliculas_navideñas
# Out:
#                                                    rating  runtime  \
# title
# Love Actually                                           R    135.0
# Home Alone                                             PG    103.0
# National Lampoon's Christmas Vacation               PG-13     97.0
# Elf                                                    PG     97.0
# How the Grinch Stole Christmas                         PG    104.0
# ...                                                   ...      ...
# CBS News Sunday Morning with Jane Pauley: Episo...   TV-G      NaN
# Honest Ads: If Holiday Movies Were Honest             NaN      NaN
# Cosmic Cowboys: Céréal Christmas                      NaN      NaN
# Proper Manors: Christmas Special: Christmas Par...    NaN     20.0
# Sacred Music at Christmas: A Choral Christmas         NaN      NaN
#
#                                                     imdb_rating  meta_score  \
# title
# ...

# %%
df_Peliculas_navideñas.fillna("Sin datos", inplace=True)
# Out:
# C:\Users\Kathe\AppData\Local\Temp\ipykernel_24040\2527898454.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Sin datos' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_Peliculas_navideñas.fillna("Sin datos", inplace=True)

# %%
df_Peliculas_navideñas
# Out:
#                                                        rating    runtime  \
# title
# Love Actually                                               R      135.0
# Home Alone                                                 PG      103.0
# National Lampoon's Christmas Vacation                   PG-13       97.0
# Elf                                                        PG       97.0
# How the Grinch Stole Christmas                             PG      104.0
# ...                                                       ...        ...
# CBS News Sunday Morning with Jane Pauley: Episo...       TV-G  Sin datos
# Honest Ads: If Holiday Movies Were Honest           Sin datos  Sin datos
# Cosmic Cowboys: Céréal Christmas                    Sin datos  Sin datos
# Proper Manors: Christmas Special: Christmas Par...  Sin datos       20.0
# Sacred Music at Christmas: A Choral Christmas       Sin datos  Sin datos
#
#                                                    imdb_rating meta_score  \
# title
# ...

# %%
df_Peliculas_navideñas.to_excel("Peliculas_navideñas_excel.xlsx")

# %%
df_Peliculas_navideñas_excel= pd.read_excel("Peliculas_navideñas_excel.xlsx", index_col=0)

# %%
df_Peliculas_navideñas_excel
# Out:
#                                                        rating    runtime  \
# title
# Love Actually                                               R        135
# Home Alone                                                 PG        103
# National Lampoon's Christmas Vacation                   PG-13         97
# Elf                                                        PG         97
# How the Grinch Stole Christmas                             PG        104
# ...                                                       ...        ...
# CBS News Sunday Morning with Jane Pauley: Episo...       TV-G  Sin datos
# Honest Ads: If Holiday Movies Were Honest           Sin datos  Sin datos
# Cosmic Cowboys: Céréal Christmas                    Sin datos  Sin datos
# Proper Manors: Christmas Special: Christmas Par...  Sin datos         20
# Sacred Music at Christmas: A Choral Christmas       Sin datos  Sin datos
#
#                                                    imdb_rating meta_score  \
# title
# ...

# %%
##Crear una carpeta llamada Files y guardar el mismo archivo en esa carpeta en formato csv .
df_Peliculas_navideñas_excel.to_csv("./Files/Peliculas_navideñas_csv.csv")

# %%
#df_Personal_json= pd.read_json("./Files/personal.json")

# %%
##Copia el archivo personal.json en la carpeta Files.

##Abre el json y haz las modificaciones necesarias para poder abrirlo correctamente en Pandas.
##Guardar el json modificado y abrirlo en Pandas para que tenga formato de tabla.

with open("./Files/personal.json", "r") as fichero:
    personal=json.load(fichero)

# %%
personal
# Out:
# {'workers': [{'nombre': 'Ana',
#    'edad': 34,
#    'experiencia': 5,
#    'nivel': 'Senior',
#    'salario': 50000,
#    'mascota': 'gatos'},
#   {'nombre': 'Eva',
#    'edad': 37,
#    'experiencia': 2,
#    'nivel': 'Mid',
#    'salario': 35000},
#   {'nombre': 'Marta',
#    'edad': 27,
#    'experiencia': 1,
#    'nivel': 'Junior',
#    'salario': 25000},
#   {'nombre': 'Paula',
#    'edad': 30,
#    'experiencia': 3,
#    'nivel': 'Mid',
#    'salario': 35000}]}

# %%
personal_workers = personal['workers']

print(personal_workers)
# Out:
# [{'nombre': 'Ana', 'edad': 34, 'experiencia': 5, 'nivel': 'Senior', 'salario': 50000, 'mascota': 'gatos'}, {'nombre': 'Eva', 'edad': 37, 'experiencia': 2, 'nivel': 'Mid', 'salario': 35000}, {'nombre': 'Marta', 'edad': 27, 'experiencia': 1, 'nivel': 'Junior', 'salario': 25000}, {'nombre': 'Paula', 'edad': 30, 'experiencia': 3, 'nivel': 'Mid', 'salario': 35000}]

# %%
normalized = pd.json_normalize(personal['workers'])

# %%
personal
# Out:
# {'workers': [{'nombre': 'Ana',
#    'edad': 34,
#    'experiencia': 5,
#    'nivel': 'Senior',
#    'salario': 50000,
#    'mascota': 'gatos'},
#   {'nombre': 'Eva',
#    'edad': 37,
#    'experiencia': 2,
#    'nivel': 'Mid',
#    'salario': 35000},
#   {'nombre': 'Marta',
#    'edad': 27,
#    'experiencia': 1,
#    'nivel': 'Junior',
#    'salario': 25000},
#   {'nombre': 'Paula',
#    'edad': 30,
#    'experiencia': 3,
#    'nivel': 'Mid',
#    'salario': 35000}]}

# %%
normalized
# Out:
#   nombre  edad  experiencia   nivel  salario mascota
# 0    Ana    34            5  Senior    50000   gatos
# 1    Eva    37            2     Mid    35000     NaN
# 2  Marta    27            1  Junior    25000     NaN
# 3  Paula    30            3     Mid    35000     NaN

# %%
with open ("normalized.json", "w") as fichero:
    json.dump("normalized.json", fichero)

# %%
normalized
# Out:
#   nombre  edad  experiencia   nivel  salario mascota
# 0    Ana    34            5  Senior    50000   gatos
# 1    Eva    37            2     Mid    35000     NaN
# 2  Marta    27            1  Junior    25000     NaN
# 3  Paula    30            3     Mid    35000     NaN
